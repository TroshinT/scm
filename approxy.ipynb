# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import linalg

# %%
x = np.array([  0, 28, 62, 118, 155, 210, 272, 360 ])
y = np.array([  1.0, 0.69, 0.51, 0.23, 0.14, 0.067, 0.041, 0.018 ])
plt.plot(x, y, 'o', color='tab:brown')
plt.plot(x, y)
plt.grid()
pass
